# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanizakariya/Dicoding-MyIntentApp/blob/main/GAPenjadwalan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random, copy
from math import ceil, log2
import math
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
class Dosen :
  dosen = None

  def __init__(self,name):
    self.name = name

  @staticmethod
  def find(name):
    for i in range (len(Dosen.dosen)):
      if Dosen.dosen[i].name == name:
        return i
    return -1

  def __repr__(self):
    return "Dosen: " + self.name


class Kelas :
  kelas = None

  def __init__(self,name, size):
    self.name = name
    self.size = size

  @staticmethod
  def find(name):
    for i in range (len(Kelas.kelas)):
      if Kelas.kelas[i].name == name:
        return i
    return -1

  def __repr__(self):
    return "Kelas: " + self.name

class Matkul :
  mamtkul = None

  def __init__(self,name, status = False):
    self.name = name
    self.status = status

  @staticmethod
  def find(name):
    for i in range (len(Matkul.matkul)):
      if Matkul.matkul[i].name == name:
        return i
    return -1

  def __repr__(self):
    return "Matkul: " + self.name


class Ruang :
  ruang = None

  def __init__(self,name, size, status = True):
    self.name = name
    self.size = size
    self.status = status

  @staticmethod
  def find(name):
    for i in range (len(Ruang.ruang)):
      if Ruang.ruang[i].name == name:
        return i
    return -1

  def __repr__(self):
    return "Ruang: " + self.name

class Waktu :
  waktu = None

  def __init__(self, hari, mulai, selesai,  status_slot = False):
    self.mulai = mulai
    self.selesai = selesai
    self.hari = hari
    self.status_slot = status_slot

  def __repr__(self):
    return "Hari: " + self.hari + ", Pukul: " + self.mulai + "-" + self.selesai

# %%
Dosen.dosen = [Dosen("Dr. Eko Mulyanto Yuniarno, S.T.,M.T."),
               Dosen("Dr. Diah Puspito Wulandari, S.T.,M.Sc."),
               Dosen("Dr. I Ketut Eddy Purnama, S.T.,M.T."),
               Dosen("Ir. Hany Boedinugroho, M.T."),
               Dosen("Prof. Dr. Ir. Yoyon Kusnendar Suprapto, M.Sc."),
               Dosen("Prof. Dr. Ir. Mauridhi Hery Purnomo, M.Eng."),
               Dosen("Dr. Surya Sumpeno, S.T.,M.Sc."),
               Dosen("Eko Pramunanto, S.T., M.T."),
               Dosen("Arief Kurniawan, S.T., M.T."),
               Dosen("Muhtadin, S.T., M.T."),
               Dosen("Atar Fuady Babgei, S.T., M.Sc."),
               Dosen("Mochamad Hariadi, S.T.,M.Sc.,Ph.D"),
               Dosen("Dr. Supeno Mardi Susiki Nugroho, S.T., M.T."),
               Dosen("Susi Juniastuti, S.T.,M.Eng."),
               Dosen("Ahmad Zaini, S.T., M.Sc."),
               Dosen("Reza Fuad Rachmadi, S.T.,M.T.,Ph.D"),
               Dosen("Dion Hayu Fandiantoro, S.T., M.Eng.")
               ]

Kelas.kelas = [Kelas("A", 10),
               Kelas("B", 30)]

Matkul.matkul = [Matkul("Matematika Diskrit A"),
                 Matkul("Matematika Diskrit B"),
                 Matkul("Sistem Manajemen Basis Data A"),
                 Matkul("Sistem Manajemen Basis Data B"),
                 Matkul("Pemrograman Lanjut A"),
                 Matkul("Pemrograman Lanjut B"),
                 Matkul("Sistem Operasi A"),
                 Matkul("Rangkaian Digital A"),
                 Matkul("Metode Numerik A"),
                 Matkul("Metode Numerik B"),
                 Matkul("Metode Numerik C"),
                 Matkul("Proyek Telematika A"),
                 Matkul("Aljabar Linear A"),
                 Matkul("Persamaan Differensial dan Deret A"),
                 Matkul("Desain Dan Rekayasa Sistem A"),
                 Matkul("Desain Dan Rekayasa Sistem B"),
                 Matkul("Pemrograman Sistem dan Jaringan A"),
                 Matkul("Desain Pemrograman Game A"),
                 Matkul("Arsitektur dan Organisasi Sistem Komputer A"),
                 Matkul("Arsitektur dan Organisasi Sistem Komputer B"),
                 Matkul("Sistem Mikroprosesor dan Mikrokontroller A"),
                 Matkul("Persepsi Robot A"),
                 Matkul("Pra Tugas Akhir A"),
                 Matkul("Sistem Tertanam A"),
                 Matkul("Pengolahan Sinyal Digital A"),
                 Matkul("Pengantar Robotika A"),
                 Matkul("Visi Komputer A"),
                 Matkul("Probabilitas dan Statistik A"),
                 Matkul("Sekuriti Sistem Komputer A"),
                 Matkul("Jaringan Komputer A"),
                 Matkul("Jaringan Komputer B"),
                 Matkul("Deep Learning untuk Multimedia A"),
                 Matkul("Rangkaian Listrik A"),
                 Matkul("Rangkaian Listrik B"),
                 Matkul("Dasar Pemrograman P"),
                 Matkul("Desain Pemrograman Game P")]

Ruang.ruang = [Ruang("B211", 40),
               Ruang("A234", 40),
               Ruang("A235", 40),
               Ruang("A108", 40)
              ]

Waktu.waktu = [Waktu("Senin","07.30","10.00"),
               Waktu("Senin","10.00","12.30"),
               Waktu("Senin","13.30","16.00"),
               Waktu("Selasa","07.30","10.00"),
               Waktu("Selasa","10.00","12.30"),
               Waktu("Selasa","13.30","16.00"),
               Waktu("Rabu","07.30","10.00"),
               Waktu("Rabu","10.00","12.30"),
               Waktu("Rabu","13.30","16.00"),
               Waktu("Kamis","07.30","10.00"),
               Waktu("Kamis","10.00","12.30"),
               Waktu("Kamis","13.30","16.00"),
               Waktu("Jumat","07.30","10.00"),
              #  Waktu("Jumat","10.00","12.30"),
               Waktu("Jumat","13.30","16.00"),
               ]

# %%
print(Dosen.dosen[1])
# Out:
# Dosen: Dr. Diah Puspito Wulandari, S.T.,M.Sc.

# %%
individu1 = [[random.randint(1, len(Dosen.dosen)), 
              random.randint(1, len(Matkul.matkul)),
               random.randint(1, len(Ruang.ruang)),
               random.randint(1, len(Waktu.waktu))
               ] 
              for i in range (len(Matkul.matkul))]

individu2 = [[random.randint(1, len(Dosen.dosen)), 
              random.randint(1, len(Matkul.matkul)),
               random.randint(1, len(Ruang.ruang)),
               random.randint(1, len(Waktu.waktu))
               ] 
              for i in range (len(Matkul.matkul))]
print(individu1)
print(individu2)
# Out:
# [[9, 31, 4, 7], [1, 32, 2, 2], [12, 25, 4, 5], [3, 33, 1, 4], [17, 22, 3, 5], [4, 21, 1, 12], [13, 16, 1, 6], [14, 29, 1, 11], [6, 3, 1, 1], [16, 21, 3, 1], [13, 35, 1, 3], [6, 33, 1, 9], [4, 20, 1, 14], [4, 17, 2, 2], [16, 26, 3, 7], [11, 7, 3, 5], [15, 7, 2, 8], [16, 36, 4, 8], [5, 36, 2, 4], [12, 31, 2, 2], [2, 32, 1, 5], [13, 32, 1, 11], [15, 35, 2, 11], [2, 17, 4, 14], [17, 6, 1, 11], [13, 12, 2, 9], [14, 19, 4, 13], [8, 16, 1, 8], [12, 26, 2, 14], [17, 22, 2, 4], [15, 31, 3, 2], [11, 8, 3, 7], [1, 17, 4, 11], [1, 1, 2, 7], [2, 6, 3, 5], [16, 32, 4, 2]]
# [[14, 18, 4, 9], [17, 29, 4, 4], [16, 18, 4, 6], [8, 31, 2, 9], [14, 15, 4, 14], [10, 29, 4, 5], [9, 21, 2, 2], [7, 17, 1, 9], [6, 10, 2, 10], [9, 8, 2, 2], [16, 30, 4, 4], [9, 28, 3, 1], [11, 1, 4, 2], [12, 4, 2, 2], [5, 6, 1, 4], [12, 13, 1, 14], [3, 35, 1, 14], [17, 6, 1, 4], [2, 21, 1, 5], [10, 17, 1, 4], [12, 2, 1, 2], [7, 29, 1, 9], [10, 26, 3, 7], [10, 9, 3, 8], [7, 2, 1, 12], [3, 16, 2, 11], [2, 31, 1, 10], [1, 19, 3, 13], [14, 32, 2, 13], [6, 6, 4, 11], [5, 2, 1, 3], [12, 28, 1, 14], [3, 2, 2, 13], [12, 18, 4, 10], [4, 22, 4, 10], [7, 4, 1, 3]]

# %%
print(len(individu1))
# Out:
# 36

# %%
def sorting(sub_li):
    l = len(sub_li)
    for i in range(0, l):
        for j in range(0, l-i-1):
            if (sub_li[j][3] > sub_li[j + 1][3]):
                tempo = sub_li[j]
                sub_li[j]= sub_li[j + 1]
                sub_li[j + 1]= tempo
    return sub_li

# %%
individu1 = sorting(individu1)
individu2 = sorting(individu2)
print(len(individu1))
print(individu1)
print(individu2)
# Out:
# 36
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [13, 35, 1, 3], [3, 33, 1, 4], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [11, 7, 3, 5], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [1, 1, 2, 7], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[9, 28, 3, 1], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [10, 9, 3, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [2, 31, 1, 10], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]

# %%
def cetak(a):
  print("Jadwal Semester Ganjil")
  for i in range (0,35) :
    for j in range (0,3):
      print(Waktu.waktu[(a[i][3])-1],' | ',
            Ruang.ruang[(a[i][2])-1],' | ',
            Matkul.matkul[(a[i][1])-1],' | ',
            Dosen.dosen[(a[i][0])-1],
            )

# %%
#satu matkul hanya dilakukan satu kali
def cek_matkul(a):
  score = 0
  for i in range (len(a)):
    for j in range (i+1, len(a)):
      if a[i][1] == a[i+1][1] and j<=len(a):
        score = score + 1
  return score

# %%
#satu ruangan hanya dipakai satu kali dalam satu waktu
def cek_ruang(a):
  score = 0
  for i in range (len(a)):
    for j in range (i+1, len(a)):
      if a[i][2] == a[i+1][2] and a[i][3] == a[i+1][3] and j<=len(a):
        score = score + 1
  return score

# %%
#satu dosen hanya bisa mengajar dalam satu waktu
def cek_dosen(a):
  score = 0
  for i in range (len(a)):
    for j in range (i+1, len(a)):
      if a[i][0] == a[i+1][0] and a[i][3] == a[i+1][3] and j<=len(a):
        score = score+1
  return score

# %%
def fitness(a):
  score = 0
  score = score + cek_matkul(a)
  score = score + cek_dosen(a)
  return 1/(score+1)

# %%
def crossover(a,b):
  a = list(a)
  b = list(b)
  c = list(a)
  d = list(b)
  print("Before")
  print(a)
  print(b)

  n = random.randint(1, ((len(a)-1)))
  print("crossover point :", n)

  for i in range (n, len(a)):
    a[i],b[i] = b[i],a[i]

  fit_a = float(fitness(a))
  fit_b = float(fitness(b))
  fit_c = float(fitness(c))
  fit_d = float(fitness(d))
  print(fit_a)
  print(fit_b)
  print(fit_c)
  print(fit_d)
  _ = ['a','b','c','d']
  fit = [fit_a,fit_b,fit_c,fit_d]
  pair = dict(zip(fit,_))
  fit_sorted = dict(reversed(sorted(pair.items())))
  result = fit_sorted.values()
  print(fit_sorted.values())


crossover(individu1, individu2)
# Out:
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [13, 35, 1, 3], [3, 33, 1, 4], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [11, 7, 3, 5], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [1, 1, 2, 7], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[9, 28, 3, 1], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [10, 9, 3, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [2, 31, 1, 10], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]
# crossover point : 26
# 0.018867924528301886
# 0.007352941176470588
# 0.018867924528301886
# 0.007352941176470588
# dict_values(['c', 'd'])

# %%
def mutate(a,b, mut_rate):
  n = len(a) + len(b)
  print (n)
  print("Before")
  print(a)
  print(b)
  total_mutation = int(abs(mut_rate * n))
  for i in range (total_mutation):
    c = [random.randint(1, len(Dosen.dosen)),
       random.randint(1, len(Matkul.matkul)),
       random.randint(1, len(Ruang.ruang)),
       random.randint(1, len(Waktu.waktu))]
    x = random.randint(0,n)
    print(x)
    if x <= 35 :
      a[x] = c
    else :
      b[x-len(b)-1] = c
  print("after")
  print(a)
  print(b)
  print("Fitness a:", fitness(a))
  print("Fitness b:", fitness(b))
  # new_a = a
  # neb_b = b
  return a,b

  

mutate(individu1, individu2, 0.1)
# print(individu1)
# print(individu2)
# Out:
# 72
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [13, 35, 1, 3], [3, 33, 1, 4], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [11, 7, 3, 5], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [1, 1, 2, 7], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[9, 28, 3, 1], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [10, 9, 3, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [2, 31, 1, 10], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]
# 37
# 60
# 20
# 54
# 13
# 8
# 7
# after
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [14, 3, 4, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]
# Fitness a: 0.018867924528301886
# Fitness b: 0.007352941176470588
# ([[6, 3, 1, 1],
#   [16, 21, 3, 1],
#   [1, 32, 2, 2],
#   [4, 17, 2, 2],
#   [12, 31, 2, 2],
#   [15, 31, 3, 2],
#   [16, 32, 4, 2],
#   [7, 34, 4, 14],
#   [11, 26, 2, 2],
#   [5, 36, 2, 4],
#   [17, 22, 2, 4],
#   [12, 25, 4, 5],
#   [17, 22, 3, 5],
#   [4, 9, 3, 7],
#   [2, 32, 1, 5],
#   [2, 6, 3, 5],
#   [13, 16, 1, 6],
#   [9, 31, 4, 7],
#   [16, 26, 3, 7],
#   [11, 8, 3, 7],
#   [5, 2, 1, 11],
#   [15, 7, 2, 8],
#   [16, 36, 4, 8],
#   [8, 16, 1, 8],
#   [6, 33, 1, 9],
#   [13, 12, 2, 9],
#   [14, 29, 1, 11],
#   [13, 32, 1, 11],
#   [15, 35, 2, 11],
#   [17, 6, 1, 11],
#   [1, 17, 4, 11],
#   [4, 21, 1, 12],
#   [14, 19, 4, 13],
#   [4, 20, 1, 14],
#   [2, 17, 4, 14],
#   [12, 26, 2, 14]],
#  [[12, 32, 3, 5],
#   [9, 21, 2, 2],
#   [9, 8, 2, 2],
#   [11, 1, 4, 2],
#   [12, 4, 2, 2],
#   [12, 2, 1, 2],
#   [5, 2, 1, 3],
#   [7, 4, 1, 3],
#   [17, 29, 4, 4],
#   [16, 30, 4, 4],
#   [5, 6, 1, 4],
#   [17, 6, 1, 4],
#   [10, 17, 1, 4],
#   [10, 29, 4, 5],
#   [2, 21, 1, 5],
#   [16, 18, 4, 6],
#   [10, 26, 3, 7],
#   [14, 3, 4, 8],
#   [14, 18, 4, 9],
#   [8, 31, 2, 9],
#   [7, 17, 1, 9],
#   [7, 29, 1, 9],
#   [6, 10, 2, 10],
#   [12, 6, 4, 12],
#   [12, 18, 4, 10],
#   [4, 22, 4, 10],
#   [3, 16, 2, 11],
#   [6, 6, 4, 11],
#   [7, 2, 1, 12],
#   [1, 19, 3, 13],
#   [14, 32, 2, 13],
#   [3, 2, 2, 13],
#   [14, 15, 4, 14],
#   [12, 13, 1, 14],
#   [3, 35, 1, 14],
#   [12, 28, 1, 14]])

# %%
def gA(a,b,rate):
  generation = 0
  score1 = 0
  score2 = 0
  while True:
    if score1 == 1.00 or score2==1.00 or generation == 500:
      print("Stop")
      break
    else:
      # a = list(a)
      # b = list(b)
      # c = list(a)
      # d = list(b)
      score1 = fitness(a)
      score2 = fitness(b)
      # score3 = fitness(c)
      # score4 = fitness(d)
      # if score1 > score3 and score2 > score4

      
      c = crossover(a,b)
      a,b = mutate(a,b,rate)
      generation = generation + 1
      print("Generation : ", generation)
      # print("Fitness :", score1, score2)

gA(individu1,individu2,0.1)
# Out:
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [14, 3, 4, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]
# crossover point : 3
# 0.00980392156862745
# 0.011494252873563218
# 0.018867924528301886
# 0.007352941176470588
# dict_values(['c', 'b', 'a', 'd'])
# 72
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [12, 25, 4, 5], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [16, 36, 4, 8], [8, 16, 1, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [12, 2, 1, 2], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [5, 6, 1, 4], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [14, 3, 4, 8], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [12, 28, 1, 14]]
# 42
# 11
# 47
# 22
# 72
# 54
# 23
# after
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# Fitness a: 0.018867924528301886
# Fitness b: 0.02
# Generation :  1
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# crossover point : 24
# 0.018867924528301886
# 0.02
# 0.018867924528301886
# 0.02
# dict_values(['d', 'c'])
# 72
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [1, 32, 2, 2], [4, 17, 2, 2], [12, 31, 2, 2], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [11, 8, 3, 7], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [12, 26, 2, 14]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [11, 1, 4, 2], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [16, 18, 4, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [14, 32, 2, 13], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# 4
# 67
# 52
# 2
# 40
# 35
# 19
# after
# [[6, 3, 1, 1], [16, 21, 3, 1], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [15, 12, 2, 11], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# Fitness a: 0.045454545454545456
# Fitness b: 0.02
# Generation :  2
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [15, 12, 2, 11], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# crossover point : 18
# 0.02702702702702703
# 0.02857142857142857
# 0.045454545454545456
# 0.02
# dict_values(['c', 'b', 'a', 'd'])
# 72
# Before
# [[6, 3, 1, 1], [16, 21, 3, 1], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [15, 12, 2, 11], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [1, 17, 4, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 16, 2, 11], [6, 6, 4, 11], [7, 2, 1, 12], [1, 19, 3, 13], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [13, 12, 2, 7]]
# 63
# 1
# 19
# 72
# 30
# 72
# 66
# after
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [6, 6, 4, 11], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [8, 19, 4, 14]]
# Fitness a: 0.037037037037037035
# Fitness b: 0.01694915254237288
# Generation :  3
# Before
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [6, 6, 4, 11], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [8, 19, 4, 14]]
# crossover point : 21
# 0.03225806451612903
# 0.025
# 0.037037037037037035
# 0.01694915254237288
# dict_values(['c', 'a', 'b', 'd'])
# 72
# Before
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [5, 36, 2, 4], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [4, 9, 3, 7], [2, 32, 1, 5], [2, 6, 3, 5], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [17, 6, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [7, 29, 1, 9], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [6, 6, 4, 11], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [8, 19, 4, 14]]
# 64
# 9
# 72
# 48
# 13
# 58
# 15
# after
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [5, 22, 2, 2], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [1, 3, 4, 6]]
# Fitness a: 0.16666666666666666
# Fitness b: 0.02857142857142857
# Generation :  4
# Before
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [5, 22, 2, 2], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [1, 3, 4, 6]]
# crossover point : 33
# 0.16666666666666666
# 0.02857142857142857
# 0.16666666666666666
# 0.02857142857142857
# dict_values(['c', 'd'])
# 72
# Before
# [[6, 3, 1, 1], [17, 21, 1, 11], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [17, 22, 3, 5], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [13, 12, 2, 9], [14, 29, 1, 11], [13, 32, 1, 11], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [5, 22, 2, 2], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [1, 3, 4, 6]]
# 25
# 58
# 12
# 27
# 12
# 36
# 1
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# Fitness a: 0.034482758620689655
# Fitness b: 0.02857142857142857
# Generation :  5
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# crossover point : 1
# 0.02857142857142857
# 0.034482758620689655
# 0.034482758620689655
# 0.02857142857142857
# dict_values(['c', 'd'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [16, 32, 4, 2], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [7, 35, 2, 6], [5, 2, 1, 11], [15, 7, 2, 8], [8, 16, 3, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [17, 6, 1, 11], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [4, 7, 4, 1], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [14, 18, 4, 9], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [12, 19, 2, 6], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# 55
# 42
# 29
# 22
# 6
# 19
# 66
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [15, 23, 2, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# Fitness a: 0.019230769230769232
# Fitness b: 0.02857142857142857
# Generation :  6
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [15, 23, 2, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# crossover point : 30
# 0.024390243902439025
# 0.025
# 0.019230769230769232
# 0.02857142857142857
# dict_values(['d', 'b', 'a', 'c'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [15, 23, 2, 9], [7, 6, 4, 8], [6, 33, 1, 9], [5, 1, 4, 14], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [5, 28, 2, 8]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [10, 17, 1, 4], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [3, 35, 1, 14], [3, 19, 3, 10]]
# 25
# 22
# 22
# 23
# 35
# 49
# 71
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# Fitness a: 0.016129032258064516
# Fitness b: 0.02857142857142857
# Generation :  7
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# crossover point : 10
# 1.0
# 0.010416666666666666
# 0.016129032258064516
# 0.02857142857142857
# dict_values(['a', 'd', 'c', 'b'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [2, 24, 1, 9], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [7, 18, 1, 6], [7, 36, 2, 1], [2, 36, 4, 9], [2, 32, 1, 5], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [16, 26, 3, 7], [3, 26, 3, 4], [5, 2, 1, 11], [15, 7, 2, 8], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [4, 23, 4, 12], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [8, 31, 2, 9], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# 14
# 11
# 30
# 2
# 56
# 21
# 18
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# Fitness a: 0.029411764705882353
# Fitness b: 0.02857142857142857
# Generation :  8
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# crossover point : 17
# 0.041666666666666664
# 0.022222222222222223
# 0.029411764705882353
# 0.02857142857142857
# dict_values(['a', 'c', 'd', 'b'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [7, 34, 4, 14], [11, 26, 2, 2], [11, 12, 2, 12], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [4, 20, 1, 14], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [10, 26, 3, 7], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [6, 20, 3, 11], [1, 5, 2, 1], [7, 2, 1, 12], [9, 29, 1, 10], [6, 27, 1, 11], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# 33
# 9
# 67
# 64
# 63
# 7
# 53
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# Fitness a: 0.029411764705882353
# Fitness b: 0.02857142857142857
# Generation :  9
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# crossover point : 19
# 0.041666666666666664
# 0.022222222222222223
# 0.029411764705882353
# 0.02857142857142857
# dict_values(['a', 'c', 'd', 'b'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [7, 36, 2, 1], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [11, 18, 1, 6], [4, 28, 1, 10], [9, 3, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [2, 17, 4, 14], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [9, 8, 2, 2], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [12, 13, 1, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# 34
# 39
# 12
# 70
# 21
# 23
# 39
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [4, 35, 1, 3], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [2, 4, 4, 1], [4, 28, 1, 10], [16, 1, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [11, 34, 2, 1], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [6, 8, 3, 8], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [4, 22, 3, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# Fitness a: 0.09090909090909091
# Fitness b: 1.0
# Generation :  10
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [4, 35, 1, 3], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [2, 4, 4, 1], [4, 28, 1, 10], [16, 1, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [11, 34, 2, 1], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [6, 8, 3, 8], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [4, 22, 3, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# crossover point : 34
# 0.09090909090909091
# 1.0
# 0.09090909090909091
# 1.0
# dict_values(['d', 'c'])
# 72
# Before
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [5, 30, 4, 1], [5, 1, 3, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [4, 35, 1, 3], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [2, 4, 4, 1], [4, 28, 1, 10], [16, 1, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [15, 35, 2, 11], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [1, 23, 1, 13], [11, 34, 2, 1], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [6, 8, 3, 8], [9, 19, 4, 13], [12, 4, 2, 2], [14, 3, 2, 13], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [15, 4, 1, 6], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [4, 22, 3, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# 12
# 7
# 6
# 42
# 33
# 28
# 52
# after
# [[6, 3, 1, 1], [2, 17, 3, 10], [1, 28, 1, 4], [4, 17, 2, 2], [11, 15, 2, 9], [15, 31, 3, 2], [6, 36, 1, 7], [9, 13, 4, 9], [11, 26, 2, 2], [16, 10, 2, 7], [17, 22, 2, 4], [1, 9, 1, 11], [8, 36, 3, 10], [2, 36, 4, 9], [7, 35, 3, 3], [15, 33, 2, 1], [13, 16, 1, 6], [9, 31, 4, 7], [2, 5, 1, 11], [3, 26, 3, 4], [5, 2, 1, 11], [2, 4, 4, 1], [4, 28, 1, 10], [16, 1, 3, 3], [6, 33, 1, 9], [7, 29, 4, 9], [14, 29, 1, 11], [1, 26, 4, 14], [14, 9, 4, 5], [8, 23, 2, 14], [14, 17, 2, 11], [4, 21, 1, 12], [14, 19, 4, 13], [13, 18, 3, 9], [11, 34, 2, 1], [8, 2, 2, 9]]
# [[12, 32, 3, 5], [9, 21, 2, 2], [6, 8, 3, 8], [9, 19, 4, 13], [12, 4, 2, 2], [15, 18, 3, 11], [5, 2, 1, 3], [7, 4, 1, 3], [17, 29, 4, 4], [16, 30, 4, 4], [8, 20, 2, 10], [7, 11, 1, 4], [6, 30, 1, 12], [10, 29, 4, 5], [2, 21, 1, 5], [2, 7, 2, 7], [8, 32, 3, 4], [15, 17, 3, 10], [15, 23, 2, 14], [12, 18, 4, 5], [7, 17, 1, 9], [12, 24, 2, 6], [6, 10, 2, 10], [12, 6, 4, 12], [12, 18, 4, 10], [4, 22, 4, 10], [3, 29, 1, 10], [7, 26, 3, 6], [7, 2, 1, 12], [9, 29, 1, 10], [12, 21, 4, 10], [3, 2, 2, 13], [14, 15, 4, 14], [4, 22, 3, 14], [14, 35, 4, 3], [3, 19, 3, 10]]
# Fitness a: 0.029411764705882353
# Fitness b: 1.0
# Generation :  11
# Stop

# %%
a = random.random()
print(a)
# Out:
# 0.3065788935695991

# %%
score = []
b = 0
# cek_matkul(individu1)
for i in range (len(a)):
  cek_matkul(a[i])
  score.append(b)
  print(b)
  b = 0
print(score)
print(len(score))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b8e04b0b8c43> in <cell line: 4>()
#       2 b = 0
#       3 # cek_matkul(individu1)
# ----> 4 for i in range (len(a)):
#       5   cek_matkul(a[i])
#       6   score.append(b)
#
# TypeError: object of type 'float' has no len()

# %%
def cek_kelas(a):
  global score
  for i in range (0, 54):
    # print(i)
    for j in range (i+1, 55):
      if population[i][2] == population [i+1][2] and j <= 55:
        score = score + 1
  return score

# %%
score: float = 0.0
generation = 0
  
# def fitness(population):
#   global score

# %%
def evaluate(population):
  score = 0
  score = score + cek_kelas(population)
  return score
evaluate(population)
print(score)

# %%
population = [5]
def init_gen(total_pop, dosen, ruang, waktu):
  global population
  for i in range (total_pop):
    # print(ruang)
    population[i] = [[random.randint(1, dosen), 
                      #  random.randint(1, len(Matkul.matkul)),
                      random.randint(1, ruang),
                      random.randint(1, waktu)
                      ] for j in range (ruang*waktu)]
    # print("populasi ke " + i + ":" + population[i])

init_gen(3, len(Dosen.dosen), len(Ruang.ruang), len(Waktu.waktu))

# %%
import random
  
# Number of individuals in each generation
POPULATION_SIZE = 100
  
# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
  
# Target string to be generated
TARGET = "I love GeeksforGeeks"
  
class Individual(object):
    # '''
    # Class representing individual in population
    # '''
    def __init__(self, chromosome):
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness()
  
    @classmethod
    def mutated_genes(self):
        # '''
        # create random genes for mutation
        # '''
        global GENES
        gene = random.choice(GENES)
        return gene
  
    @classmethod
    def create_gnome(self):
        # '''
        # create chromosome or string of genes
        # '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
  
    def mate(self, par2):
        # '''
        # Perform mating and produce new offspring
        # '''
  
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):    
  
            # random probability  
            prob = random.random()
  
            # if prob is less than 0.45, insert gene
            # from parent 1 
            if prob < 0.45:
                child_chromosome.append(gp1)
  
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
  
            # otherwise insert random gene(mutate), 
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
  
        # create new Individual(offspring) using 
        # generated chromosome for offspring
        return Individual(child_chromosome)
  
    def cal_fitness(self):
        # '''
        # Calculate fitness score, it is the number of
        # characters in string which differ from target
        # string.
        # '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
  
# Driver code
def main():
    global POPULATION_SIZE
  
    #current generation
    generation = 1
  
    found = False
    population = []
  
    # create initial population
    for _ in range(POPULATION_SIZE):
                gnome = Individual.create_gnome()
                population.append(Individual(gnome))
  
    while not found:
  
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
  
        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
  
        # Otherwise generate new offsprings for new generation
        new_generation = []
  
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
  
        # From 50% of fittest population, Individuals 
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
  
        population = new_generation
  
        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))
  
        generation += 1
  
      
    print("Generation: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))
  
if __name__ == '__main__':
    main()

# %%
a = []
for i in range (1):
  individu = [[random.randint(1, len(Dosen.dosen)), 
              random.randint(1, len(Matkul.matkul)),
               random.randint(1, len(Ruang.ruang)),
               random.randint(1, len(Waktu.waktu))
               ] 
              for i in range (len(Ruang.ruang)*len(Waktu.waktu))]
  sort(individu)
  print(individu)
  a.append(individu)

print(a)
